# %%
#Data collection
#Data preprocessing
#Explotary Data Analysis
#Conclusions

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import plotly.offline as py
import seaborn as sns
import gc
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Web Scraping

# %%
 
from bs4 import BeautifulSoup as soup
from datetime import date, datetime
from urllib.request import Request, urlopen

# %%
 url = "https://www.worldometers.info/coronavirus/#countries"

# %%
req= Request(url, headers={'User-Agent' : 'Mozilla/5.0' })
webpage= urlopen(req)
page_soup= soup(webpage,"html.parser")

# %%
today = datetime.now()
yesterday_str= "%s %d,%d" %(date.today().strftime("%b"), today.day-1, today.year)
yesterday_str
# Out:
# 'Dec 12,2021'

# %%
table = page_soup.findAll("table",{"id": "main_table_countries_yesterday"})
containers = table[0].findAll("tr",{"style":""})
title = containers[0]
clean=True
del containers[0]
all_data = []

for country in containers:
    country_data = []
    country_container = country.findAll("td")
    
    if country_container[1].text == "China":
        continue
    for i in range(1, len(country_container)):
        final_feature = country_container[i].text
        if clean :
            if i != 1 and i!= len(country_container)-1:
                final_feature= final_feature.replace(",","")
                
                if final_feature.find('+') != -1:
                    final_feature=final_feature.replace("+","")
                    final_feature = float(final_feature)
                elif final_feature.find('-') != -1:
                    final_feature=final_feature.replace("-","")
                    final_feature = float(final_feature)*-1
        if final_feature ==  'N/A':
            final_feature= 0
        elif final_feature == "" or final_feature == " ":
            final_feature = -1
        
        country_data.append(final_feature)
    
    all_data.append(country_data)

# %%
all_data
# Out:
# [['World',
#   '270438946',
#   441278.0,
#   '5322062',
#   4249.0,
#   '243106547',
#   354924.0,
#   '22010337',
#   '88809',
#   '34695',
#   '682.8',
#   -1,
#   -1,
#   -1,
#   'All',
#   '\n',
#   -1,
#   -1,
#   -1,
#   -1,
#   -1],
#  ['USA',
#   '50801455',
#   38784.0,
#   '817956 ',
#   167.0,
#   '40003674',
#   17538.0,
#   '9979825',
#   '15001',
#   '152188',
#   '2450',
#   '773733664',
#   '2317902',
#   '333807743 ',
#   'North America',
#   '7',
#   '408',
#   '0',
#   '116',
#   '0.5',
#   '29,897'],
#  ['India',
#   '34697860',
#   7350.0,
#   '475636  ',
#   202.0,
#   '34122795',
#   8464.0,
#   '99429',
#   '8944',
#   '24791',
#   '340',
#   '655816759',
#   '468572',
#   '1399605867 ',
#   'Asia',
#   '40',
#   '2943',
#   '2',
#   '5',
#   '0.1',
#   '71'],
#  ['Brazil',
#   '22189867',
#   1688.0,
#   '616941 ',
#   82.0,
#   '21414318',
#   -1,
#   '158608',
#   '8318',
#   '103332',
#   '2873',
#   '63776166',
#   '296989',
#   '214742837 ',
#   'South America',
#   '10',
#   '348',
#   '3',
#   '8',
#   '0.4',
#   '739'],
#  ['UK',
#   '10819515',
#   48854.0,
#   '146439 ',
#   52.0,
#   '9490407',
#   36978.0,
#   '1182669',
#   '900',
#   '158177',
#   '2141',
#   '374468898',
#   '5474580',
#   '68401397 ',
#   'Europe',
#   '6',
#   '467',
#   '0',
#   '714',
#   '0.8',
#   '17,290'],
#  ['Russia',
#   '10016896',
#   29929.0,
#   '289483 ',
#   1132.0,
#   '8741355',
#   31391.0,
#   '986058',
#   '2300',
#   '68597',
#   '1982',
#   '231600000',
#   '1586031',
#   '146024926 ',
#   'Europe',
#   '15',
#   '504',
#   '1',
#   '205',
#   '8',
#   '6,753'],
#  ['Turkey',
#   '9040179',
#   17956.0,
#   '79151 ',
#   182.0,
#   '8614742',
#   22648.0,
#   '346286',
#   '1128',
#   '105548',
#   '924',
#   '111908324',
#   '1306576',
#   '85650085 ',
#   'Asia',
#   '9',
#   '1082',
#   '1',
#   '210',
#   '2',
#   '4,043'],
#  ['France',
#   '8258692',
#   43848.0,
#   '120431 ',
#   48.0,
#   '7299854',
#   5201.0,
#   '838407',
#   '2602',
#   '126121',
#   '1839',
#   '172371975',
#   '2632345',
#   '65482298 ',
#   'Europe',
#   '8',
#   '544',
#   '0',
#   '670',
#   '0.7',
#   '12,804'],
#  ['Germany',
#   '6530912',
#   29633.0,
#   '106331 ',
#   123.0,
#   '5395300',
#   27000.0,
#   '1029281',
#   '4636',
#   '77591',
#   '1263',
#   '87852398',
#   '1043735',
#   '84171180 ',
#   'Europe',
#   '13',
#   '792',
#   '1',
#   '352',
#   '1',
#   '12,228'],
#  ['Iran',
#   '6154813',
#   2289.0,
#   '130722 ',
#   61.0,
#   '5969591',
#   6218.0,
#   '54500',
#   '3104',
#   '71948',
#   '1528',
#   '40054772',
#   '468227',
#   '85545694 ',
#   'Asia',
#   '14',
#   '654',
#   '2',
#   '27',
#   '0.7',
#   '637'],
#  ['Argentina',
#   '5358455',
#   1570.0,
#   '116771 ',
#   11.0,
#   '5216007',
#   2329.0,
#   '25677',
#   '693',
#   '117010',
#   '2550',
#   '26686014',
#   '582728',
#   '45794974 ',
#   'South America',
#   '9',
#   '392',
#   '2',
#   '34',
#   '0.2',
#   '561'],
#  ['Spain',
#   '5290190',
#   -1,
#   '88381 ',
#   -1,
#   '4943735',
#   -1,
#   '258074',
#   '1056',
#   '113084',
#   '1889',
#   '66213858',
#   '1415402',
#   '46780959 ',
#   'Europe',
#   '9',
#   '529',
#   '1',
#   -1,
#   -1,
#   '5,517'],
#  ['Italy',
#   '5225517',
#   19215.0,
#   '134831 ',
#   66.0,
#   '4805809',
#   8151.0,
#   '284877',
#   '829',
#   '86611',
#   '2235',
#   '125992518',
#   '2088275',
#   '60333284 ',
#   'Europe',
#   '12',
#   '447',
#   '0',
#   '318',
#   '1',
#   '4,722'],
#  ['Colombia',
#   '5093534',
#   2026.0,
#   '129107 ',
#   51.0,
#   '4933825',
#   1521.0,
#   '30602',
#   '342',
#   '98585',
#   '2499',
#   '28625046',
#   '554036',
#   '51666366 ',
#   'South America',
#   '10',
#   '400',
#   '2',
#   '39',
#   '1.0',
#   '592'],
#  ['Indonesia',
#   '4259143',
#   163.0,
#   '143936 ',
#   7.0,
#   '4110049',
#   184.0,
#   '5158',
#   -1,
#   '15337',
#   '518',
#   '58183343',
#   '209517',
#   '277701960 ',
#   'Asia',
#   '65',
#   '1929',
#   '5',
#   '0.6',
#   '0.03',
#   '19'],
#  ['Mexico',
#   '3917361',
#   2655.0,
#   '296620 ',
#   235.0,
#   '3271058',
#   2022.0,
#   '349683',
#   '4798',
#   '29929',
#   '2266',
#   '12065033',
#   '92177',
#   '130889685 ',
#   'North America',
#   '33',
#   '441',
#   '11',
#   '20',
#   '2',
#   '2,672'],
#  ['Poland',
#   '3828246',
#   19450.0,
#   '88479 ',
#   65.0,
#   '3289117',
#   25554.0,
#   '450650',
#   '2142',
#   '101312',
#   '2342',
#   '25609282',
#   '677733',
#   '37786681 ',
#   'Europe',
#   '10',
#   '427',
#   '1',
#   '515',
#   '2',
#   '11,926'],
#  ['Ukraine',
#   '3559092',
#   5275.0,
#   '91027 ',
#   238.0,
#   '3195913',
#   11626.0,
#   '272152',
#   '177',
#   '82094',
#   '2100',
#   '16294537',
#   '375850',
#   '43353809 ',
#   'Europe',
#   '12',
#   '476',
#   '3',
#   '122',
#   '5',
#   '6,277'],
#  ['South Africa',
#   '3167497',
#   37875.0,
#   '90137 ',
#   21.0,
#   '2913232',
#   32760.0,
#   '164128',
#   '546',
#   '52452',
#   '1493',
#   '20238805',
#   '335142',
#   '60388725 ',
#   'Africa',
#   '19',
#   '670',
#   '3',
#   '627',
#   '0.3',
#   '2,718'],
#  ['Netherlands',
#   '2880426',
#   16588.0,
#   '20112 ',
#   38.0,
#   '2249161',
#   16134.0,
#   '611153',
#   '637',
#   '167567',
#   '1170',
#   '19205114',
#   '1117247',
#   '17189677 ',
#   'Europe',
#   '6',
#   '855',
#   '1',
#   '965',
#   '2',
#   '35,553'],
#  ['Philippines',
#   '2836443',
#   253.0,
#   '50280 ',
#   184.0,
#   '2774860',
#   312.0,
#   '11303',
#   '899',
#   '25396',
#   '450',
#   '24673354',
#   '220914',
#   '111687507 ',
#   'Asia',
#   '39',
#   '2221',
#   '5',
#   '2',
#   '2',
#   '101'],
#  ['Malaysia',
#   '2691639',
#   3490.0,
#   '30879 ',
#   17.0,
#   '2601908',
#   5399.0,
#   '58852',
#   '407',
#   '81652',
#   '937',
#   '39173380',
#   '1188335',
#   '32964936 ',
#   'Asia',
#   '12',
#   '1068',
#   '1',
#   '106',
#   '0.5',
#   '1,785'],
#  ['Czechia',
#   '2334291',
#   9082.0,
#   '34498 ',
#   73.0,
#   '2053197',
#   236.0,
#   '246596',
#   '1012',
#   '217392',
#   '3213',
#   '45474681',
#   '4235049',
#   '10737700 ',
#   'Europe',
#   '5',
#   '311',
#   '0',
#   '846',
#   '7',
#   '22,965'],
#  ['Peru',
#   '2251027',
#   -1,
#   '201650 ',
#   -1,
#   0,
#   0,
#   0,
#   '993',
#   '66925',
#   '5995',
#   '20753581',
#   '617020',
#   '33635157 ',
#   'South America',
#   '15',
#   '167',
#   '2',
#   -1,
#   -1,
#   '9,773'],
#  ['Thailand',
#   '2168646',
#   3787.0,
#   '21169 ',
#   20.0,
#   '2095859',
#   5606.0,
#   '51618',
#   '1369',
#   '30957',
#   '302',
#   '14913135',
#   '212883',
#   '70053155 ',
#   'Asia',
#   '32',
#   '3309',
#   '5',
#   '54',
#   '0.3',
#   '737'],
#  ['Iraq',
#   '2087837',
#   340.0,
#   '23978 ',
#   13.0,
#   '2055454',
#   758.0,
#   '8405',
#   '76',
#   '50279',
#   '577',
#   '16553566',
#   '398643',
#   '41524753 ',
#   'Asia',
#   '20',
#   '1732',
#   '3',
#   '8',
#   '0.3',
#   '202'],
#  ['Belgium',
#   '1929772',
#   -1,
#   '27504 ',
#   -1,
#   '1421499',
#   -1,
#   '480769',
#   '827',
#   '165468',
#   '2358',
#   '25785017',
#   '2210929',
#   '11662524 ',
#   'Europe',
#   '6',
#   '424',
#   '0',
#   -1,
#   -1,
#   '41,223'],
#  ['Canada',
#   '1835229',
#   3496.0,
#   '29919 ',
#   9.0,
#   '1766728',
#   846.0,
#   '38582',
#   '469',
#   '48017',
#   '783',
#   '49829014',
#   '1303732',
#   '38220281 ',
#   'North America',
#   '21',
#   '1277',
#   '1',
#   '91',
#   '0.2',
#   '1,009'],
#  ['Romania',
#   '1793149',
#   716.0,
#   '57704 ',
#   45.0,
#   '1715859',
#   1620.0,
#   '19586',
#   '722',
#   '94118',
#   '3029',
#   '16418691',
#   '861778',
#   '19052105 ',
#   'Europe',
#   '11',
#   '330',
#   '1',
#   '38',
#   '2',
#   '1,028'],
#  ['Chile',
#   '1782804',
#   1577.0,
#   '38686 ',
#   40.0,
#   '1682379',
#   2932.0,
#   '61739',
#   '670',
#   '92119',
#   '1999',
#   '26341034',
#   '1361062',
#   '19353294 ',
#   'South America',
#   '11',
#   '500',
#   '1',
#   '81',
#   '2',
#   '3,190'],
#  ['Japan',
#   '1728689',
#   141.0,
#   '18373 ',
#   1.0,
#   '1709386',
#   116.0,
#   '930',
#   '25',
#   '13729',
#   '146',
#   '28470838',
#   '226109',
#   '125916628 ',
#   'Asia',
#   '73',
#   '6853',
#   '4',
#   '1',
#   '0.01',
#   '7'],
#  ['Bangladesh',
#   '1579325',
#   329.0,
#   '28028 ',
#   6.0,
#   '1544150',
#   288.0,
#   '7147',
#   '1369',
#   '9454',
#   '168',
#   '11120198',
#   '66564',
#   '167059797 ',
#   'Asia',
#   '106',
#   '5960',
#   '15',
#   '2',
#   '0.04',
#   '43'],
#  ['Vietnam',
#   '1413051',
#   14638.0,
#   '27839 ',
#   228.0,
#   '1054720',
#   1295.0,
#   '330492',
#   '7596',
#   '14331',
#   '282',
#   '71322461',
#   '723322',
#   '98603978 ',
#   'Asia',
#   '70',
#   '3542',
#   '1',
#   '148',
#   '2',
#   '3,352'],
#  ['Israel',
#   '1350215',
#   443.0,
#   '8216 ',
#   6.0,
#   '1336391',
#   834.0,
#   '5608',
#   '100',
#   '144780',
#   '881',
#   '36081323',
#   '3868896',
#   '9326000 ',
#   'Asia',
#   '7',
#   '1135',
#   '0',
#   '48',
#   '0.6',
#   '601'],
#  ['Pakistan',
#   '1289049',
#   288.0,
#   '28830 ',
#   7.0,
#   '1251101',
#   674.0,
#   '9118',
#   '740',
#   '5677',
#   '127',
#   '22525190',
#   '99194',
#   '227082831 ',
#   'Asia',
#   '176',
#   '7877',
#   '10',
#   '1',
#   '0.03',
#   '40'],
#  ['Serbia',
#   '1274047',
#   944.0,
#   '12178 ',
#   30.0,
#   '1229344',
#   2596.0,
#   '32525',
#   '177',
#   '146670',
#   '1402',
#   '6976359',
#   '803128',
#   '8686481 ',
#   'Europe',
#   '7',
#   '713',
#   '1',
#   '109',
#   '3',
#   '3,744'],
#  ['Sweden',
#   '1229217',
#   -1,
#   '15158 ',
#   -1,
#   '1167277',
#   925.0,
#   '46782',
#   '48',
#   '120627',
#   '1487',
#   '13934770',
#   '1367458',
#   '10190271 ',
#   'Europe',
#   '8',
#   '672',
#   '1',
#   -1,
#   -1,
#   '4,591'],
#  ['Austria',
#   '1228034',
#   2479.0,
#   '13162 ',
#   19.0,
#   '1144860',
#   6138.0,
#   '70012',
#   '568',
#   '135236',
#   '1449',
#   '114668040',
#   '12627714',
#   '9080665 ',
#   'Europe',
#   '7',
#   '690',
#   '0',
#   '273',
#   '2',
#   '7,710'],
#  ['Portugal',
#   '1194288',
#   3879.0,
#   '18658 ',
#   13.0,
#   '1107513',
#   1397.0,
#   '68117',
#   '143',
#   '117621',
#   '1838',
#   '22787039',
#   '2244206',
#   '10153720 ',
#   'Europe',
#   '9',
#   '544',
#   '0',
#   '382',
#   '1',
#   '6,709'],
#  ['Hungary',
#   '1182922',
#   -1,
#   '36429 ',
#   -1,
#   '968897',
#   -1,
#   '177596',
#   '573',
#   '122902',
#   '3785',
#   '8768881',
#   '911064',
#   '9624884 ',
#   'Europe',
#   '8',
#   '264',
#   '1',
#   -1,
#   -1,
#   '18,452'],
#  ['Switzerland',
#   '1127066',
#   5215.0,
#   '11808 ',
#   8.0,
#   '895436',
#   3931.0,
#   '219822',
#   '273',
#   '128865',
#   '1350',
#   '13030943',
#   '1489918',
#   '8746081 ',
#   'Europe',
#   '8',
#   '741',
#   '1',
#   '596',
#   '0.9',
#   '25,134'],
#  ['Jordan',
#   '1010033',
#   3897.0,
#   '11982 ',
#   41.0,
#   '931323',
#   3971.0,
#   '66728',
#   '1295',
#   '97593',
#   '1158',
#   '12733099',
#   '1230314',
#   '10349470 ',
#   'Asia',
#   '10',
#   '864',
#   '1',
#   '377',
#   '4',
#   '6,447'],
#  ['Greece',
#   '1002877',
#   3225.0,
#   '19245 ',
#   88.0,
#   '919746',
#   7414.0,
#   '63886',
#   '708',
#   '96902',
#   '1860',
#   '40616801',
#   '3924544',
#   '10349433 ',
#   'Europe',
#   '10',
#   '538',
#   '0',
#   '312',
#   '9',
#   '6,173'],
#  ['Kazakhstan',
#   '979484',
#   554.0,
#   '12852 ',
#   15.0,
#   '948214',
#   631.0,
#   '18418',
#   '528',
#   '51279',
#   '673',
#   '11575012',
#   '605986',
#   '19101121 ',
#   'Asia',
#   '20',
#   '1486',
#   '2',
#   '29',
#   '0.8',
#   '964'],
#  ['Cuba',
#   '963628',
#   62.0,
#   '8313 ',
#   -1,
#   '954927',
#   65.0,
#   '388',
#   '16',
#   '85152',
#   '735',
#   '11328647',
#   '1001063',
#   '11316621 ',
#   'North America',
#   '12',
#   '1361',
#   '1',
#   '5',
#   -1,
#   '34'],
#  ['Morocco',
#   '951482',
#   102.0,
#   '14796 ',
#   -1,
#   '935067',
#   328.0,
#   '1619',
#   '103',
#   '25344',
#   '394',
#   '10567009',
#   '281468',
#   '37542500 ',
#   'Africa',
#   '39',
#   '2537',
#   '4',
#   '3',
#   -1,
#   '43'],
#  ['Georgia',
#   '889286',
#   2922.0,
#   '12731 ',
#   36.0,
#   '832675',
#   4999.0,
#   '43880',
#   -1,
#   '223546',
#   '3200',
#   '12133846',
#   '3050164',
#   '3978096 ',
#   'Asia',
#   '4',
#   '312',
#   '0',
#   '735',
#   '9',
#   '11,030'],
#  ['Nepal',
#   '824222',
#   242.0,
#   '11554 ',
#   1.0,
#   '806778',
#   234.0,
#   '5890',
#   '114',
#   '27572',
#   '387',
#   '4714778',
#   '157720',
#   '29893294 ',
#   'Asia',
#   '36',
#   '2587',
#   '6',
#   '8',
#   '0.03',
#   '197'],
#  ['Slovakia',
#   '774857',
#   4913.0,
#   '15354 ',
#   50.0,
#   '652657',
#   7507.0,
#   '106846',
#   '581',
#   '141825',
#   '2810',
#   '4857976',
#   '889175',
#   '5463465 ',
#   'Europe',
#   '7',
#   '356',
#   '1',
#   '899',
#   '9',
#   '19,556'],
#  ['UAE',
#   '742802',
#   83.0,
#   '2151 ',
#   -1,
#   '737896',
#   75.0,
#   '2755',
#   -1,
#   '73815',
#   '214',
#   '104695497',
#   '10403997',
#   '10063007 ',
#   'Asia',
#   '14',
#   '4678',
#   '0',
#   '8',
#   -1,
#   '274'],
#  ['Tunisia',
#   '719586',
#   152.0,
#   '25432 ',
#   5.0,
#   '692768',
#   151.0,
#   '1386',
#   '50',
#   '59979',
#   '2120',
#   '3229686',
#   '269202',
#   '11997273 ',
#   'Africa',
#   '17',
#   '472',
#   '4',
#   '13',
#   '0.4',
#   '116'],
#  ['Bulgaria',
#   '714688',
#   532.0,
#   '29536 ',
#   50.0,
#   '587577',
#   451.0,
#   '97575',
#   '629',
#   '103988',
#   '4298',
#   '6906046',
#   '1004837',
#   '6872801 ',
#   'Europe',
#   '10',
#   '233',
#   '1',
#   '77',
#   '7',
#   '14,197'],
#  ['Lebanon',
#   '690054',
#   1539.0,
#   '8848 ',
#   12.0,
#   '640860',
#   -1,
#   '40346',
#   '186',
#   '101759',
#   '1305',
#   '4795578',
#   '707182',
#   '6781247 ',
#   'Asia',
#   '10',
#   '766',
#   '1',
#   '227',
#   '2',
#   '5,950'],
#  ['Belarus',
#   '674723',
#   1454.0,
#   '5276 ',
#   15.0,
#   '665432',
#   1977.0,
#   '4015',
#   -1,
#   '71438',
#   '559',
#   '10671855',
#   '1129915',
#   '9444829 ',
#   'Europe',
#   '14',
#   '1790',
#   '1',
#   '154',
#   '2',
#   '425'],
#  ['Croatia',
#   '654202',
#   2339.0,
#   '11619 ',
#   45.0,
#   '617482',
#   3676.0,
#   '25101',
#   '326',
#   '160791',
#   '2856',
#   '3578293',
#   '879478',
#   '4068657 ',
#   'Europe',
#   '6',
#   '350',
#   '1',
#   '575',
#   '11',
#   '6,169'],
#  ['Ireland',
#   '623623',
#   4667.0,
#   '5788 ',
#   -1,
#   '484213',
#   5478.0,
#   '133622',
#   '109',
#   '124291',
#   '1154',
#   '9313992',
#   '1856315',
#   '5017462 ',
#   'Europe',
#   '8',
#   '867',
#   '1',
#   '930',
#   -1,
#   '26,631'],
#  ['Guatemala',
#   '622168',
#   324.0,
#   '16036 ',
#   7.0,
#   '605184',
#   367.0,
#   '948',
#   '5',
#   '33825',
#   '872',
#   '3186458',
#   '173234',
#   '18393935 ',
#   'North America',
#   '30',
#   '1147',
#   '6',
#   '18',
#   '0.4',
#   '52'],
#  ['Azerbaijan',
#   '604480',
#   1226.0,
#   '8088 ',
#   18.0,
#   '576264',
#   1649.0,
#   '20128',
#   -1,
#   '58852',
#   '787',
#   '5677746',
#   '552782',
#   '10271218 ',
#   'Asia',
#   '17',
#   '1270',
#   '2',
#   '119',
#   '2',
#   '1,960'],
#  ['Sri Lanka',
#   '572902',
#   714.0,
#   '14614 ',
#   19.0,
#   '545051',
#   425.0,
#   '13237',
#   -1,
#   '26593',
#   '678',
#   '5726599',
#   '265822',
#   '21543018 ',
#   'Asia',
#   '38',
#   '1474',
#   '4',
#   '33',
#   '0.9',
#   '614'],
#  ['Costa Rica',
#   '567995',
#   -1,
#   '7332 ',
#   -1,
#   '558639',
#   -1,
#   '2024',
#   '64',
#   '110048',
#   '1421',
#   '2839020',
#   '550056',
#   '5161326 ',
#   'North America',
#   '9',
#   '704',
#   '2',
#   -1,
#   -1,
#   '392'],
#  ['Denmark',
#   '554389',
#   5989.0,
#   '3014 ',
#   9.0,
#   '475922',
#   4281.0,
#   '75453',
#   '65',
#   '95228',
#   '518',
#   '98706173',
#   '16954915',
#   '5821685 ',
#   'Europe',
#   '11',
#   '1932',
#   '0',
#   '1029',
#   '2',
#   '12,961'],
#  ['Bolivia',
#   '552586',
#   1070.0,
#   '19305 ',
#   -1,
#   '503707',
#   805.0,
#   '29574',
#   '220',
#   '46424',
#   '1622',
#   '2602670',
#   '218657',
#   '11902979 ',
#   'South America',
#   '22',
#   '617',
#   '5',
#   '90',
#   -1,
#   '2,485'],
#  ['Saudi Arabia',
#   '550240',
#   51.0,
#   '8853 ',
#   1.0,
#   '539477',
#   68.0,
#   '1910',
#   '29',
#   '15458',
#   '249',
#   '31980191',
#   '898403',
#   '35596721 ',
#   'Asia',
#   '65',
#   '4021',
#   '1',
#   '1',
#   '0.03',
#   '54'],
#  ['Ecuador',
#   '533190',
#   -1,
#   '33558 ',
#   -1,
#   '443880',
#   -1,
#   '55752',
#   '759',
#   '29573',
#   '1861',
#   '2053558',
#   '113897',
#   '18029903 ',
#   'South America',
#   '34',
#   '537',
#   '9',
#   -1,
#   -1,
#   '3,092'],
#  ['Myanmar',
#   '526661',
#   280.0,
#   '19183 ',
#   6.0,
#   '503107',
#   441.0,
#   '4371',
#   -1,
#   '9587',
#   '349',
#   '5794026',
#   '105467',
#   '54936904 ',
#   'Asia',
#   '104',
#   '2864',
#   '9',
#   '5',
#   '0.1',
#   '80'],
#  ['S. Korea',
#   '517271',
#   6688.0,
#   '4253 ',
#   43.0,
#   '431606',
#   2350.0,
#   '81412',
#   '856',
#   '10077',
#   '83',
#   '15804065',
#   '307874',
#   '51332971 ',
#   'Asia',
#   '99',
#   '12070',
#   '3',
#   '130',
#   '0.8',
#   '1,586'],
#  ['Lithuania',
#   '491125',
#   1241.0,
#   '6978 ',
#   19.0,
#   '456294',
#   232.0,
#   '27853',
#   '125',
#   '184125',
#   '2616',
#   '6349830',
#   '2380580',
#   '2667346 ',
#   'Europe',
#   '5',
#   '382',
#   '0',
#   '465',
#   '7',
#   '10,442'],
#  ['Panama',
#   '480781',
#   208.0,
#   '7386 ',
#   -1,
#   '470285',
#   176.0,
#   '3110',
#   '14',
#   '108950',
#   '1674',
#   '4310101',
#   '976718',
#   '4412839 ',
#   'North America',
#   '9',
#   '597',
#   '1',
#   '47',
#   -1,
#   '705'],
#  ['Paraguay',
#   '463755',
#   48.0,
#   '16505 ',
#   3.0,
#   '446598',
#   53.0,
#   '652',
#   '54',
#   '63886',
#   '2274',
#   '1981198',
#   '272927',
#   '7259086 ',
#   'South America',
#   '16',
#   '440',
#   '4',
#   '7',
#   '0.4',
#   '90'],
#  ['Slovenia',
#   '439952',
#   783.0,
#   '5409 ',
#   15.0,
#   '412022',
#   1466.0,
#   '22521',
#   '243',
#   '211581',
#   '2601',
#   '1995840',
#   '959838',
#   '2079351 ',
#   'Europe',
#   '5',
#   '384',
#   '1',
#   '377',
#   '7',
#   '10,831'],
#  ['Venezuela',
#   '438683',
#   796.0,
#   '5239 ',
#   5.0,
#   '426476',
#   903.0,
#   '6968',
#   '681',
#   '15491',
#   '185',
#   '3359014',
#   '118612',
#   '28319443 ',
#   'South America',
#   '65',
#   '5406',
#   '8',
#   '28',
#   '0.2',
#   '246'],
#  ['Palestine',
#   '433985',
#   305.0,
#   '4576 ',
#   7.0,
#   '425777',
#   270.0,
#   '3632',
#   '62',
#   '82311',
#   '868',
#   '2781723',
#   '527591',
#   '5272498 ',
#   'Asia',
#   '12',
#   '1152',
#   '2',
#   '58',
#   '1',
#   '689'],
#  ['Kuwait',
#   '413711',
#   39.0,
#   '2466 ',
#   -1,
#   '410898',
#   34.0,
#   '347',
#   '3',
#   '94849',
#   '565',
#   '5571126',
#   '1277262',
#   '4361772 ',
#   'Asia',
#   '11',
#   '1769',
#   '1',
#   '9',
#   -1,
#   '80'],
#  ['Dominican Republic',
#   '410265',
#   178.0,
#   '4218 ',
#   -1,
#   '404389',
#   216.0,
#   '1658',
#   '110',
#   '37280',
#   '383',
#   '2505224',
#   '227643',
#   '11005069 ',
#   'North America',
#   '27',
#   '2609',
#   '4',
#   '16',
#   -1,
#   '151'],
#  ['Uruguay',
#   '402509',
#   126.0,
#   '6145 ',
#   3.0,
#   '394078',
#   169.0,
#   '2286',
#   '13',
#   '115295',
#   '1760',
#   '4212437',
#   '1206611',
#   '3491131 ',
#   'South America',
#   '9',
#   '568',
#   '1',
#   '36',
#   '0.9',
#   '655'],
#  ['Mongolia',
#   '385353',
#   157.0,
#   '2033 ',
#   2.0,
#   '313256',
#   -1,
#   '70064',
#   '192',
#   '114876',
#   '606',
#   '4030048',
#   '1201381',
#   '3354514 ',
#   'Asia',
#   '9',
#   '1650',
#   '1',
#   '47',
#   '0.6',
#   '20,886'],
#  ['Honduras',
#   '378561',
#   -1,
#   '10421 ',
#   -1,
#   '122591',
#   -1,
#   '245549',
#   '51',
#   '37363',
#   '1029',
#   '1126954',
#   '111227',
#   '10132056 ',
#   'North America',
#   '27',
#   '972',
#   '9',
#   -1,
#   -1,
#   '24,235'],
#  ['Libya',
#   '378105',
#   655.0,
#   '5553 ',
#   13.0,
#   '363780',
#   1603.0,
#   '8772',
#   -1,
#   '53967',
#   '793',
#   '1951115',
#   '278483',
#   '7006234 ',
#   'Africa',
#   '19',
#   '1262',
#   '4',
#   '93',
#   '2',
#   '1,252'],
#  ['Ethiopia',
#   '373115',
#   115.0,
#   '6829 ',
#   -1,
#   '350368',
#   76.0,
#   '15918',
#   '157',
#   '3134',
#   '57',
#   '3932787',
#   '33029',
#   '119071101 ',
#   'Africa',
#   '319',
#   '17436',
#   '30',
#   '1.0',
#   -1,
#   '134'],
#  ['Moldova',
#   '369659',
#   257.0,
#   '9368 ',
#   14.0,
#   '354258',
#   293.0,
#   '6033',
#   '132',
#   '91946',
#   '2330',
#   '2273501',
#   '565490',
#   '4020407 ',
#   'Europe',
#   '11',
#   '429',
#   '2',
#   '64',
#   '3',
#   '1,501'],
#  ['Egypt',
#   '369198',
#   863.0,
#   '21060 ',
#   45.0,
#   '306605',
#   499.0,
#   '41533',
#   '90',
#   '3512',
#   '200',
#   '3693367',
#   '35135',
#   '105120314 ',
#   'Africa',
#   '285',
#   '4991',
#   '28',
#   '8',
#   '0.4',
#   '395'],
#  ['Armenia',
#   '342538',
#   133.0,
#   '7802 ',
#   14.0,
#   '325394',
#   560.0,
#   '9342',
#   -1,
#   '115284',
#   '2626',
#   '2447762',
#   '823816',
#   '2971249 ',
#   'Asia',
#   '9',
#   '381',
#   '1',
#   '45',
#   '5',
#   '3,144'],
#  ['Norway',
#   '317880',
#   3622.0,
#   '1136 ',
#   -1,
#   '88952',
#   -1,
#   '227792',
#   '109',
#   '57981',
#   '207',
#   '8837513',
#   '1611951',
#   '5482494 ',
#   'Europe',
#   '17',
#   '4826',
#   '1',
#   '661',
#   -1,
#   '41,549'],
#  ['Oman',
#   '304714',
#   11.0,
#   '4113 ',
#   -1,
#   '300096',
#   30.0,
#   '505',
#   '2',
#   '57559',
#   '777',
#   '25000000',
#   '4722376',
#   '5293945 ',
#   'Asia',
#   '17',
#   '1287',
#   '0',
#   '2',
#   -1,
#   '95'],
#  ['Bosnia and Herzegovina',
#   '281628',
#   109.0,
#   '12961 ',
#   12.0,
#   '192218',
#   -1,
#   '76449',
#   -1,
#   '86620',
#   '3986',
#   '1426356',
#   '438702',
#   '3251308 ',
#   'Europe',
#   '12',
#   '251',
#   '2',
#   '34',
#   '4',
#   '23,513'],
#  ['Bahrain',
#   '278065',
#   28.0,
#   '1394 ',
#   -1,
#   '276355',
#   34.0,
#   '316',
#   '1',
#   '155622',
#   '780',
#   '7626655',
#   '4268348',
#   '1786793 ',
#   'Asia',
#   '6',
#   '1282',
#   '0',
#   '16',
#   -1,
#   '177'],
#  ['Singapore',
#   '273362',
#   370.0,
#   '794 ',
#   5.0,
#   '267028',
#   830.0,
#   '5540',
#   '30',
#   '46201',
#   '134',
#   '21098774',
#   '3565894',
#   '5916826 ',
#   'Asia',
#   '22',
#   '7452',
#   '0',
#   '63',
#   '0.8',
#   '936'],
#  ['Latvia',
#   '261944',
#   481.0,
#   '4375 ',
#   9.0,
#   '248267',
#   1374.0,
#   '9302',
#   '97',
#   '141131',
#   '2357',
#   '5450653',
#   '2936717',
#   '1856036 ',
#   'Europe',
#   '7',
#   '424',
#   '0',
#   '259',
#   '5',
#   '5,012'],
#  ['Kenya',
#   '256335',
#   201.0,
#   '5348 ',
#   2.0,
#   '248515',
#   4.0,
#   '2472',
#   '1',
#   '4620',
#   '96',
#   '2889613',
#   '52084',
#   '55480276 ',
#   'Africa',
#   '216',
#   '10374',
#   '19',
#   '4',
#   '0.04',
#   '45'],
#  ['Qatar',
#   '245354',
#   166.0,
#   '613 ',
#   1.0,
#   '242336',
#   121.0,
#   '2405',
#   '9',
#   '87383',
#   '218',
#   '3061355',
#   '1090302',
#   '2807805 ',
#   'Asia',
#   '11',
#   '4580',
#   '1',
#   '59',
#   '0.4',
#   '857'],
#  ['Australia',
#   '228930',
#   1542.0,
#   '2104 ',
#   4.0,
#   '210848',
#   1284.0,
#   '15978',
#   '99',
#   '8830',
#   '81',
#   '50006586',
#   '1928726',
#   '25927259 ',
#   'Australia/Oceania',
#   '113',
#   '12323',
#   '1',
#   '59',
#   '0.2',
#   '616'],
#  ['Estonia',
#   '228279',
#   377.0,
#   '1852 ',
#   4.0,
#   '213179',
#   210.0,
#   '13248',
#   '23',
#   '171919',
#   '1395',
#   '2401703',
#   '1808750',
#   '1327825 ',
#   'Europe',
#   '6',
#   '717',
#   '1',
#   '284',
#   '3',
#   '9,977'],
#  ['North Macedonia',
#   '219408',
#   308.0,
#   '7732 ',
#   9.0,
#   '205946',
#   246.0,
#   '5730',
#   -1,
#   '105320',
#   '3712',
#   '1502730',
#   '721339',
#   '2083250 ',
#   'Europe',
#   '9',
#   '269',
#   '1',
#   '148',
#   '4',
#   '2,751'],
#  ['Nigeria',
#   '217481',
#   418.0,
#   '2981 ',
#   -1,
#   '207746',
#   43.0,
#   '6754',
#   '11',
#   '1019',
#   '14',
#   '3629527',
#   '16999',
#   '213509157 ',
#   'Africa',
#   '982',
#   '71623',
#   '59',
#   '2',
#   -1,
#   '32'],
#  ['Algeria',
#   '212848',
#   196.0,
#   '6145 ',
#   8.0,
#   '146340',
#   168.0,
#   '60363',
#   '24',
#   '4731',
#   '137',
#   '230861',
#   '5131',
#   '44994071 ',
#   'Africa',
#   '211',
#   '7322',
#   '195',
#   '4',
#   '0.2',
#   '1,342'],
#  ['Zambia',
#   '211077',
#   118.0,
#   '3670 ',
#   1.0,
#   '206670',
#   64.0,
#   '737',
#   '16',
#   '11036',
#   '192',
#   '2778680',
#   '145280',
#   '19126321 ',
#   'Africa',
#   '91',
#   '5212',
#   '7',
#   '6',
#   '0.05',
#   '39'],
#  ['Albania',
#   '203787',
#   263.0,
#   '3134 ',
#   2.0,
#   '195247',
#   409.0,
#   '5406',
#   '23',
#   '70926',
#   '1091',
#   '1420872',
#   '494517',
#   '2873254 ',
#   'Europe',
#   '14',
#   '917',
#   '2',
#   '92',
#   '0.7',
#   '1,881'],
#  ['Finland',
#   '201051',
#   -1,
#   '1421 ',
#   -1,
#   '46000',
#   -1,
#   '153630',
#   '54',
#   '36205',
#   '256',
#   '8150123',
#   '1467654',
#   '5553163 ',
#   'Europe',
#   '28',
#   '3908',
#   '1',
#   -1,
#   -1,
#   '27,665'],
#  ['Botswana',
#   '196090',
#   -1,
#   '2421 ',
#   -1,
#   '192452',
#   -1,
#   '1217',
#   '1',
#   '81024',
#   '1000',
#   '1929047',
#   '797077',
#   '2420151 ',
#   'Africa',
#   '12',
#   '1000',
#   '1',
#   -1,
#   -1,
#   '503'],
#  ['Uzbekistan',
#   '195747',
#   223.0,
#   '1436 ',
#   2.0,
#   '192461',
#   201.0,
#   '1850',
#   '23',
#   '5729',
#   '42',
#   '1377915',
#   '40326',
#   '34169663 ',
#   'Asia',
#   '175',
#   '23795',
#   '25',
#   '7',
#   '0.06',
#   '54'],
#  ['Kyrgyzstan',
#   '183965',
#   34.0,
#   '2770 ',
#   2.0,
#   '179009',
#   47.0,
#   '2186',
#   '131',
#   '27541',
#   '415',
#   '1866882',
#   '279490',
#   '6679600 ',
#   'Asia',
#   '36',
#   '2411',
#   '4',
#   '5',
#   '0.3',
#   '327'],
#  ['Zimbabwe',
#   '167140',
#   2138.0,
#   '4738 ',
#   3.0,
#   '129776',
#   214.0,
#   '32626',
#   '12',
#   '11014',
#   '312',
#   '1702579',
#   '112194',
#   '15175364 ',
#   'Africa',
#   '91',
#   '3203',
#   '9',
#   '141',
#   '0.2',
#   '2,150'],
#  ['Montenegro',
#   '159788',
#   153.0,
#   '2350 ',
#   1.0,
#   '155339',
#   251.0,
#   '2099',
#   '60',
#   '254366',
#   '3741',
#   '927554',
#   '1476571',
#   '628181 ',
#   'Europe',
#   '4',
#   '267',
#   '1',
#   '244',
#   '2',
#   '3,341'],
#  ['Afghanistan',
#   '157634',
#   11.0,
#   '7328 ',
#   3.0,
#   '141203',
#   -1,
#   '9103',
#   '1124',
#   '3922',
#   '182',
#   '803811',
#   '19999',
#   '40193249 ',
#   'Asia',
#   '255',
#   '5485',
#   '50',
#   '0.3',
#   '0.07',
#   '226'],
#  ['Mozambique',
#   '153674',
#   266.0,
#   '1944 ',
#   2.0,
#   '149958',
#   3.0,
#   '1772',
#   '13',
#   '4726',
#   '60',
#   '1002855',
#   '30840',
#   '32518050 ',
#   'Africa',
#   '212',
#   '16727',
#   '32',
#   '8',
#   '0.06',
#   '54'],
#  ['Cyprus',
#   '140851',
#   393.0,
#   '610 ',
#   2.0,
#   '124370',
#   -1,
#   '15871',
#   '55',
#   '115446',
#   '500',
#   '9477138',
#   '7767770',
#   '1220059 ',
#   'Asia',
#   '9',
#   '2000',
#   '0',
#   '322',
#   '2',
#   '13,008'],
#  ['Namibia',
#   '132849',
#   578.0,
#   '3577 ',
#   -1,
#   '125946',
#   57.0,
#   '3326',
#   '4',
#   '50952',
#   '1372',
#   '816778',
#   '313262',
#   '2607329 ',
#   'Africa',
#   '20',
#   '729',
#   '3',
#   '222',
#   -1,
#   '1,276'],
#  ['Ghana',
#   '131547',
#   135.0,
#   '1243 ',
#   4.0,
#   '129566',
#   71.0,
#   '738',
#   '5',
#   '4110',
#   '39',
#   '2018574',
#   '63063',
#   '32008928 ',
#   'Africa',
#   '243',
#   '25751',
#   '16',
#   '4',
#   '0.1',
#   '23'],
#  ['Uganda',
#   '127973',
#   60.0,
#   '3268 ',
#   1.0,
#   '97778',
#   19.0,
#   '26927',
#   '100',
#   '2676',
#   '68',
#   '2019433',
#   '42227',
#   '47823040 ',
#   'Africa',
#   '374',
#   '14634',
#   '24',
#   '1',
#   '0.02',
#   '563'],
#  ['El Salvador',
#   '121127',
#   75.0,
#   '3795 ',
#   2.0,
#   '104756',
#   1774.0,
#   '12576',
#   '232',
#   '18539',
#   '581',
#   '1473136',
#   '225474',
#   '6533505 ',
#   'North America',
#   '54',
#   '1722',
#   '4',
#   '11',
#   '0.3',
#   '1,925'],
#  ['Cambodia',
#   '120355',
#   12.0,
#   '2985 ',
#   3.0,
#   '116708',
#   13.0,
#   '662',
#   -1,
#   '7058',
#   '175',
#   '2736887',
#   '160492',
#   '17053119 ',
#   'Asia',
#   '142',
#   '5713',
#   '6',
#   '0.7',
#   '0.2',
#   '39'],
#  ['Cameroon',
#   '107549',
#   -1,
#   '1823 ',
#   -1,
#   '102716',
#   -1,
#   '3010',
#   '152',
#   '3911',
#   '66',
#   '1751774',
#   '63703',
#   '27498980 ',
#   'Africa',
#   '256',
#   '15084',
#   '16',
#   -1,
#   -1,
#   '109'],
#  ['Rwanda',
#   '100634',
#   50.0,
#   '1344 ',
#   -1,
#   '45522',
#   -1,
#   '53768',
#   '4',
#   '7501',
#   '100',
#   '3662019',
#   '272973',
#   '13415333 ',
#   'Africa',
#   '133',
#   '9982',
#   '4',
#   '4',
#   -1,
#   '4,008'],
#  ['Luxembourg',
#   '93429',
#   -1,
#   '890 ',
#   -1,
#   '86920',
#   -1,
#   '5619',
#   '23',
#   '145827',
#   '1389',
#   '3735071',
#   '5829836',
#   '640682 ',
#   'Europe',
#   '7',
#   '720',
#   '0',
#   -1,
#   -1,
#   '8,770'],
#  ['Maldives',
#   '93119',
#   55.0,
#   '258 ',
#   1.0,
#   '90924',
#   63.0,
#   '1937',
#   '23',
#   '167998',
#   '465',
#   '1799169',
#   '3245916',
#   '554287 ',
#   'Asia',
#   '6',
#   '2148',
#   '0',
#   '99',
#   '2',
#   '3,495'],
#  ['Jamaica',
#   '91765',
#   40.0,
#   '2425 ',
#   1.0,
#   '63451',
#   49.0,
#   '25889',
#   '6',
#   '30795',
#   '814',
#   '683089',
#   '229236',
#   '2979848 ',
#   'North America',
#   '32',
#   '1229',
#   '4',
#   '13',
#   '0.3',
#   '8,688'],
#  ['Laos',
#   '89320',
#   1274.0,
#   '247 ',
#   11.0,
#   '7339',
#   -1,
#   '81734',
#   -1,
#   '12025',
#   '33',
#   '861468',
#   '115975',
#   '7428018 ',
#   'Asia',
#   '83',
#   '30073',
#   '9',
#   '172',
#   '1',
#   '11,003'],
#  ['Trinidad and Tobago',
#   '80607',
#   558.0,
#   '2407 ',
#   24.0,
#   '63949',
#   467.0,
#   '14251',
#   '22',
#   '57329',
#   '1712',
#   '472414',
#   '335989',
#   '1406039 ',
#   'North America',
#   '17',
#   '584',
#   '3',
#   '397',
#   '17',
#   '10,136'],
#  ['Senegal',
#   '74086',
#   10.0,
#   '1886 ',
#   -1,
#   '72154',
#   9.0,
#   '46',
#   '1',
#   '4263',
#   '109',
#   '890614',
#   '51243',
#   '17380263 ',
#   'Africa',
#   '235',
#   '9215',
#   '20',
#   '0.6',
#   -1,
#   '3'],
#  ['Angola',
#   '65404',
#   7.0,
#   '1737 ',
#   -1,
#   '63425',
#   8.0,
#   '242',
#   '3',
#   '1905',
#   '51',
#   '1192540',
#   '34728',
#   '34339888 ',
#   'Africa',
#   '525',
#   '19770',
#   '29',
#   '0.2',
#   -1,
#   '7'],
#  ['Réunion',
#   '63863',
#   -1,
#   '391 ',
#   -1,
#   '59685',
#   -1,
#   '3787',
#   '34',
#   '70602',
#   '432',
#   '1347378',
#   '1489564',
#   '904545 ',
#   'Africa',
#   '14',
#   '2313',
#   '1',
#   -1,
#   -1,
#   '4,187'],
#  ['Malawi',
#   '62265',
#   35.0,
#   '2308 ',
#   1.0,
#   '58855',
#   3.0,
#   '1102',
#   '67',
#   '3138',
#   '116',
#   '451301',
#   '22744',
#   '19842886 ',
#   'Africa',
#   '319',
#   '8597',
#   '44',
#   '2',
#   '0.05',
#   '56'],
#  ['Ivory Coast',
#   '61905',
#   9.0,
#   '706 ',
#   -1,
#   '60983',
#   19.0,
#   '216',
#   -1,
#   '2266',
#   '26',
#   '1176716',
#   '43071',
#   '27320463 ',
#   'Africa',
#   '441',
#   '38698',
#   '23',
#   '0.3',
#   -1,
#   '8'],
#  ['DRC',
#   '59851',
#   -1,
#   '1118 ',
#   -1,
#   '50930',
#   -1,
#   '7803',
#   -1,
#   '640',
#   '12',
#   '306299',
#   '3276',
#   '93486369 ',
#   'Africa',
#   '1562',
#   '83619',
#   '305',
#   -1,
#   -1,
#   '83'],
#  ['Guadeloupe',
#   '55284',
#   -1,
#   '748 ',
#   -1,
#   '2250',
#   -1,
#   '52286',
#   '23',
#   '138133',
#   '1869',
#   '551264',
#   '1377392',
#   '400223 ',
#   'North America',
#   '7',
#   '535',
#   '1',
#   -1,
#   -1,
#   '130,642'],
#  ['Eswatini',
#   '52643',
#   469.0,
#   '1250 ',
#   2.0,
#   '45662',
#   159.0,
#   '5731',
#   '11',
#   '44707',
#   '1062',
#   '403480',
#   '342653',
#   '1177518 ',
#   'Africa',
#   '22',
#   '942',
#   '3',
#   '398',
#   '2',
#   '4,867'],
#  ['Fiji',
#   '52589',
#   5.0,
#   '697 ',
#   -1,
#   '51157',
#   -1,
#   '735',
#   -1,
#   '58056',
#   '769',
#   '465125',
#   '513478',
#   '905832 ',
#   'Australia/Oceania',
#   '17',
#   '1300',
#   '2',
#   '6',
#   -1,
#   '811'],
#  ['Suriname',
#   '51184',
#   17.0,
#   '1176 ',
#   -1,
#   '29586',
#   2.0,
#   '20422',
#   '11',
#   '86136',
#   '1979',
#   '163423',
#   '275018',
#   '594226 ',
#   'South America',
#   '12',
#   '505',
#   '4',
#   '29',
#   -1,
#   '34,367'],
#  ['Syria',
#   '49272',
#   83.0,
#   '2814 ',
#   5.0,
#   '30473',
#   97.0,
#   '15985',
#   -1,
#   '2720',
#   '155',
#   '113162',
#   '6247',
#   '18113909 ',
#   'Asia',
#   '368',
#   '6437',
#   '160',
#   '5',
#   '0.3',
#   '882'],
#  ['French Guiana',
#   '46421',
#   -1,
#   '332 ',
#   -1,
#   '11254',
#   -1,
#   '34835',
#   '5',
#   '149819',
#   '1071',
#   '462858',
#   '1493828',
#   '309847 ',
#   'South America',
#   '7',
#   '933',
#   '1',
#   -1,
#   -1,
#   '112,426'],
#  ['French Polynesia',
#   '46334',
#   -1,
#   '636 ',
#   -1,
#   0,
#   0,
#   0,
#   '7',
#   '163577',
#   '2245',
#   -1,
#   -1,
#   '283255 ',
#   'Australia/Oceania',
#   '6',
#   '445',
#   -1,
#   -1,
#   -1,
#   '43,064'],
#  ['Madagascar',
#   '45794',
#   -1,
#   '980 ',
#   -1,
#   '43393',
#   -1,
#   '1421',
#   '22',
#   '1595',
#   '34',
#   '290447',
#   '10114',
#   '28717732 ',
#   'Africa',
#   '627',
#   '29304',
#   '99',
#   -1,
#   -1,
#   '49'],
#  ['Martinique',
#   '45501',
#   -1,
#   '718 ',
#   -1,
#   '104',
#   -1,
#   '44679',
#   '1',
#   '121386',
#   '1915',
#   '416247',
#   '1110454',
#   '374844 ',
#   'North America',
#   '8',
#   '522',
#   '1',
#   -1,
#   -1,
#   '119,194'],
#  ['Sudan',
#   '44529',
#   -1,
#   '3208 ',
#   -1,
#   '36009',
#   -1,
#   '5312',
#   -1,
#   '982',
#   '71',
#   '238579',
#   '5264',
#   '45326258 ',
#   'Africa',
#   '1018',
#   '14129',
#   '190',
#   -1,
#   -1,
#   '117'],
#  ['Malta',
#   '40546',
#   78.0,
#   '470 ',
#   -1,
#   '38272',
#   94.0,
#   '1804',
#   '2',
#   '91476',
#   '1060',
#   '1211456',
#   '2733164',
#   '443243 ',
#   'Europe',
#   '11',
#   '943',
#   '0',
#   '176',
#   -1,
#   '4,070'],
#  ['Mauritania',
#   '39806',
#   28.0,
#   '849 ',
#   -1,
#   '38382',
#   35.0,
#   '575',
#   '13',
#   '8248',
#   '176',
#   '527151',
#   '109233',
#   '4825915 ',
#   'Africa',
#   '121',
#   '5684',
#   '9',
#   '6',
#   -1,
#   '119'],
#  ['Guyana',
#   '38554',
#   62.0,
#   '1020 ',
#   3.0,
#   '36639',
#   3.0,
#   '895',
#   '14',
#   '48677',
#   '1288',
#   '404841',
#   '511138',
#   '792038 ',
#   'South America',
#   '21',
#   '777',
#   '2',
#   '78',
#   '4',
#   '1,130'],
#  ['Cabo Verde',
#   '38503',
#   7.0,
#   '351 ',
#   -1,
#   '38038',
#   19.0,
#   '114',
#   '23',
#   '68182',
#   '622',
#   '211692',
#   '374869',
#   '564710 ',
#   'Africa',
#   '15',
#   '1609',
#   '3',
#   '12',
#   -1,
#   '202'],
#  ['Gabon',
#   '37591',
#   -1,
#   '282 ',
#   -1,
#   '34131',
#   -1,
#   '3178',
#   '6',
#   '16333',
#   '123',
#   '1425314',
#   '619299',
#   '2301497 ',
#   'Africa',
#   '61',
#   '8161',
#   '2',
#   -1,
#   -1,
#   '1,381'],
#  ['Papua New Guinea',
#   '35927',
#   92.0,
#   '586 ',
#   13.0,
#   '35053',
#   136.0,
#   '288',
#   '7',
#   '3909',
#   '64',
#   '249149',
#   '27106',
#   '9191648 ',
#   'Australia/Oceania',
#   '256',
#   '15685',
#   '37',
#   '10',
#   '1',
#   '31'],
#  ['Belize',
#   '31033',
#   -1,
#   '586 ',
#   -1,
#   '29609',
#   -1,
#   '838',
#   '10',
#   '76052',
#   '1436',
#   '361427',
#   '885746',
#   '408048 ',
#   'North America',
#   '13',
#   '696',
#   '1',
#   -1,
#   -1,
#   '2,054'],
#  ['Guinea',
#   '30798',
#   -1,
#   '388 ',
#   -1,
#   '29753',
#   -1,
#   '657',
#   '49',
#   '2257',
#   '28',
#   '569940',
#   '41765',
#   '13646477 ',
#   'Africa',
#   '443',
#   '35171',
#   '24',
#   -1,
#   -1,
#   '48'],
#  ['Barbados',
#   '26814',
#   74.0,
#   '252 ',
#   1.0,
#   '24536',
#   164.0,
#   '2026',
#   -1,
#   '93142',
#   '875',
#   '451177',
#   '1567218',
#   '287884 ',
#   'North America',
#   '11',
#   '1142',
#   '1',
#   '257',
#   '3',
#   '7,038'],
#  ['Togo',
#   '26400',
#   28.0,
#   '243 ',
#   -1,
#   '25945',
#   8.0,
#   '212',
#   -1,
#   '3085',
#   '28',
#   '592231',
#   '69197',
#   '8558638 ',
#   'Africa',
#   '324',
#   '35221',
#   '14',
#   '3',
#   -1,
#   '25'],
#  ['Tanzania',
#   '26309',
#   -1,
#   '734 ',
#   -1,
#   0,
#   0,
#   0,
#   '7',
#   '423',
#   '12',
#   -1,
#   -1,
#   '62187360 ',
#   'Africa',
#   '2364',
#   '84724',
#   -1,
#   -1,
#   -1,
#   '408'],
#  ['Haiti',
#   '25744',
#   -1,
#   '758 ',
#   -1,
#   '22028',
#   -1,
#   '2958',
#   -1,
#   '2219',
#   '65',
#   '132422',
#   '11412',
#   '11603304 ',
#   'North America',
#   '451',
#   '15308',
#   '88',
#   -1,
#   -1,
#   '255'],
#  ['Benin',
#   '24897',
#   -1,
#   '161 ',
#   -1,
#   '24546',
#   -1,
#   '190',
#   '5',
#   '1979',
#   '13',
#   '604310',
#   '48033',
#   '12581149 ',
#   'Africa',
#   '505',
#   '78144',
#   '21',
#   -1,
#   -1,
#   '15'],
#  ['Seychelles',
#   '23806',
#   -1,
#   '129 ',
#   -1,
#   '23294',
#   -1,
#   '383',
#   -1,
#   '239915',
#   '1300',
#   -1,
#   -1,
#   '99227 ',
#   'Africa',
#   '4',
#   '769',
#   -1,
#   -1,
#   -1,
#   '3,860'],
#  ['Lesotho',
#   '23102',
#   -1,
#   '664 ',
#   -1,
#   '13856',
#   -1,
#   '8582',
#   -1,
#   '10662',
#   '306',
#   '273169',
#   '126071',
#   '2166788 ',
#   'Africa',
#   '94',
#   '3263',
#   '8',
#   -1,
#   -1,
#   '3,961'],
#  ['Somalia',
#   '23074',
#   -1,
#   '1333 ',
#   -1,
#   '12817',
#   -1,
#   '8924',
#   -1,
#   '1396',
#   '81',
#   '262138',
#   '15856',
#   '16532573 ',
#   'Africa',
#   '717',
#   '12403',
#   '63',
#   -1,
#   -1,
#   '540'],
#  ['Bahamas',
#   '22881',
#   -1,
#   '708 ',
#   -1,
#   '21656',
#   -1,
#   '517',
#   '4',
#   '57393',
#   '1776',
#   '172649',
#   '433059',
#   '398673 ',
#   'North America',
#   '17',
#   '563',
#   '2',
#   -1,
#   -1,
#   '1,297'],
#  ['Mauritius',
#   '22613',
#   92.0,
#   '680 ',
#   -1,
#   '20962',
#   97.0,
#   '971',
#   -1,
#   '17738',
#   '533',
#   '358675',
#   '281354',
#   '1274819 ',
#   'Africa',
#   '56',
#   '1875',
#   '4',
#   '72',
#   -1,
#   '762'],
#  ['Mayotte',
#   '21088',
#   -1,
#   '185 ',
#   -1,
#   '2964',
#   -1,
#   '17939',
#   -1,
#   '74698',
#   '655',
#   '176919',
#   '626683',
#   '282310 ',
#   'Africa',
#   '13',
#   '1526',
#   '2',
#   -1,
#   -1,
#   '63,544'],
#  ['Burundi',
#   '20666',
#   -1,
#   '38 ',
#   -1,
#   '773',
#   -1,
#   '19855',
#   -1,
#   '1666',
#   '3',
#   '345742',
#   '27879',
#   '12401313 ',
#   'Africa',
#   '600',
#   '326350',
#   '36',
#   -1,
#   -1,
#   '1,601'],
#  ['Channel Islands',
#   '20327',
#   -1,
#   '107 ',
#   -1,
#   '18136',
#   -1,
#   '2084',
#   -1,
#   '115378',
#   '607',
#   '1092362',
#   '6200331',
#   '176178 ',
#   'Europe',
#   '9',
#   '1647',
#   '0',
#   -1,
#   -1,
#   '11,829'],
#  ['Timor-Leste',
#   '19829',
#   -1,
#   '122 ',
#   -1,
#   '19703',
#   -1,
#   '4',
#   -1,
#   '14637',
#   '90',
#   '211166',
#   '155878',
#   '1354690 ',
#   'Asia',
#   '68',
#   '11104',
#   '6',
#   -1,
#   -1,
#   '3'],
#  ['Iceland',
#   '19446',
#   73.0,
#   '35 ',
#   -1,
#   '17751',
#   -1,
#   '1660',
#   '5',
#   '56456',
#   '102',
#   '1281041',
#   '3719167',
#   '344443 ',
#   'Europe',
#   '18',
#   '9841',
#   '0',
#   '212',
#   -1,
#   '4,819'],
#  ['Andorra',
#   '19440',
#   -1,
#   '133 ',
#   -1,
#   '16995',
#   -1,
#   '2312',
#   '4',
#   '251020',
#   '1717',
#   '218899',
#   '2826546',
#   '77444 ',
#   'Europe',
#   '4',
#   '582',
#   '0',
#   -1,
#   -1,
#   '29,854'],
#  ['Congo',
#   '19066',
#   -1,
#   '359 ',
#   -1,
#   '12421',
#   -1,
#   '6286',
#   -1,
#   '3337',
#   '63',
#   '188207',
#   '32938',
#   '5714002 ',
#   'Africa',
#   '300',
#   '15916',
#   '30',
#   -1,
#   -1,
#   '1,100'],
#  ['Mali',
#   '18591',
#   87.0,
#   '629 ',
#   1.0,
#   '15498',
#   39.0,
#   '2464',
#   -1,
#   '881',
#   '30',
#   '506875',
#   '24032',
#   '21091786 ',
#   'Africa',
#   '1135',
#   '33532',
#   '42',
#   '4',
#   '0.05',
#   '117'],
#  ['Curaçao',
#   '17589',
#   17.0,
#   '182 ',
#   -1,
#   '17277',
#   14.0,
#   '130',
#   '3',
#   '106559',
#   '1103',
#   '352725',
#   '2136911',
#   '165063 ',
#   'North America',
#   '9',
#   '907',
#   '0',
#   '103',
#   -1,
#   '788'],
#  ['Nicaragua',
#   '17328',
#   -1,
#   '210 ',
#   -1,
#   '4225',
#   -1,
#   '12893',
#   -1,
#   '2572',
#   '31',
#   -1,
#   -1,
#   '6738399 ',
#   'North America',
#   '389',
#   '32088',
#   -1,
#   -1,
#   -1,
#   '1,913'],
#  ['Tajikistan',
#   '17095',
#   -1,
#   '124 ',
#   -1,
#   '16966',
#   -1,
#   '5',
#   -1,
#   '1736',
#   '13',
#   -1,
#   -1,
#   '9846724 ',
#   'Asia',
#   '576',
#   '79409',
#   -1,
#   -1,
#   -1,
#   '0.5'],
#  ['Taiwan',
#   '16737',
#   6.0,
#   '848 ',
#   -1,
#   '15684',
#   3.0,
#   '205',
#   -1,
#   '701',
#   '36',
#   '8702361',
#   '364434',
#   '23879090 ',
#   'Asia',
#   '1427',
#   '28159',
#   '3',
#   '0.3',
#   -1,
#   '9'],
#  ['Aruba',
#   '16593',
#   18.0,
#   '177 ',
#   -1,
#   '16213',
#   18.0,
#   '203',
#   '12',
#   '154467',
#   '1648',
#   '177885',
#   '1655961',
#   '107421 ',
#   'North America',
#   '6',
#   '607',
#   '1',
#   '168',
#   -1,
#   '1,890'],
#  ['Burkina Faso',
#   '16334',
#   -1,
#   '290 ',
#   -1,
#   '15604',
#   -1,
#   '440',
#   -1,
#   '752',
#   '13',
#   '234250',
#   '10780',
#   '21729796 ',
#   'Africa',
#   '1330',
#   '74930',
#   '93',
#   -1,
#   -1,
#   '20'],
#  ['Brunei ',
#   '15348',
#   5.0,
#   '98 ',
#   -1,
#   '14973',
#   28.0,
#   '277',
#   -1,
#   '34604',
#   '221',
#   '659767',
#   '1487533',
#   '443531 ',
#   'Asia',
#   '29',
#   '4526',
#   '1',
#   '11',
#   -1,
#   '625'],
#  ['Equatorial Guinea',
#   '13612',
#   -1,
#   '175 ',
#   -1,
#   '13386',
#   -1,
#   '51',
#   '1',
#   '9264',
#   '119',
#   '263190',
#   '179113',
#   '1469410 ',
#   'Africa',
#   '108',
#   '8397',
#   '6',
#   -1,
#   -1,
#   '35'],
#  ['Djibouti',
#   '13514',
#   -1,
#   '189 ',
#   -1,
#   '13298',
#   -1,
#   '27',
#   -1,
#   '13397',
#   '187',
#   '250716',
#   '248542',
#   '1008748 ',
#   'Africa',
#   '75',
#   '5337',
#   '4',
#   -1,
#   -1,
#   '27'],
#  ['Saint Lucia',
#   '13098',
#   -1,
#   '283 ',
#   -1,
#   '12699',
#   -1,
#   '116',
#   '6',
#   '70861',
#   '1531',
#   '102359',
#   '553771',
#   '184840 ',
#   'North America',
#   '14',
#   '653',
#   '2',
#   -1,
#   -1,
#   '628'],
#  ['New Zealand',
#   '12884',
#   103.0,
#   '46 ',
#   -1,
#   '6100',
#   26.0,
#   '6738',
#   '40',
#   '2576',
#   '9',
#   '5251593',
#   '1049878',
#   '5002100 ',
#   'Australia/Oceania',
#   '388',
#   '108741',
#   '1',
#   '21',
#   -1,
#   '1,347'],
#  ['South Sudan',
#   '12873',
#   -1,
#   '133 ',
#   -1,
#   '12576',
#   -1,
#   '164',
#   '2',
#   '1131',
#   '12',
#   '274916',
#   '24151',
#   '11383292 ',
#   'Africa',
#   '884',
#   '85589',
#   '41',
#   -1,
#   -1,
#   '14'],
#  ['Isle of Man',
#   '12580',
#   61.0,
#   '67 ',
#   -1,
#   '11740',
#   127.0,
#   '773',
#   '1',
#   '146820',
#   '782',
#   '133676',
#   '1560123',
#   '85683 ',
#   'Europe',
#   '7',
#   '1279',
#   '1',
#   '712',
#   -1,
#   '9,022'],
#  ['Hong Kong',
#   '12489',
#   5.0,
#   '213 ',
#   -1,
#   '12168',
#   3.0,
#   '108',
#   -1,
#   '1647',
#   '28',
#   '28539548',
#   '3762696',
#   '7584866 ',
#   'Asia',
#   '607',
#   '35610',
#   '0',
#   '0.7',
#   -1,
#   '14'],
#  ['New Caledonia',
#   '12379',
#   3.0,
#   '280 ',
#   -1,
#   '11921',
#   14.0,
#   '178',
#   '8',
#   '42765',
#   '967',
#   '42756',
#   '147708',
#   '289463 ',
#   'Australia/Oceania',
#   '23',
#   '1034',
#   '7',
#   '10',
#   -1,
#   '615'],
#  ['CAR',
#   '11912',
#   -1,
#   '101 ',
#   -1,
#   '6859',
#   -1,
#   '4952',
#   '2',
#   '2406',
#   '20',
#   '60228',
#   '12165',
#   '4950993 ',
#   'Africa',
#   '416',
#   '49020',
#   '82',
#   -1,
#   -1,
#   '1,000'],
#  ['Yemen',
#   '10069',
#   6.0,
#   '1971 ',
#   3.0,
#   '6942',
#   2.0,
#   '1156',
#   '23',
#   '327',
#   '64',
#   '265253',
#   '8619',
#   '30773776 ',
#   'Asia',
#   '3056',
#   '15613',
#   '116',
#   '0.2',
#   '0.10',
#   '38'],
#  ['Gambia',
#   '10034',
#   36.0,
#   '342 ',
#   -1,
#   '9641',
#   -1,
#   '51',
#   '1',
#   '3990',
#   '136',
#   '126559',
#   '50330',
#   '2514561 ',
#   'Africa',
#   '251',
#   '7353',
#   '20',
#   '14',
#   -1,
#   '20'],
#  ['Cayman Islands',
#   '7871',
#   -1,
#   '9 ',
#   -1,
#   '4339',
#   -1,
#   '3523',
#   '17',
#   '117764',
#   '135',
#   '213075',
#   '3187980',
#   '66837 ',
#   'North America',
#   '8',
#   '7426',
#   '0',
#   -1,
#   -1,
#   '52,710'],
#  ['Eritrea',
#   '7646',
#   17.0,
#   '63 ',
#   -1,
#   '7428',
#   24.0,
#   '155',
#   -1,
#   '2114',
#   '17',
#   '23693',
#   '6550',
#   '3617305 ',
#   'Africa',
#   '473',
#   '57418',
#   '153',
#   '5',
#   -1,
#   '43'],
#  ['Gibraltar',
#   '7526',
#   17.0,
#   '100 ',
#   -1,
#   '7150',
#   -1,
#   '276',
#   '3',
#   '223483',
#   '2969',
#   '428225',
#   '12716029',
#   '33676 ',
#   'Europe',
#   '4',
#   '337',
#   '0',
#   '505',
#   -1,
#   '8,196'],
#  ['Niger',
#   '7154',
#   -1,
#   '268 ',
#   -1,
#   '6823',
#   -1,
#   '63',
#   '2',
#   '281',
#   '11',
#   '195159',
#   '7663',
#   '25468936 ',
#   'Africa',
#   '3560',
#   '95033',
#   '131',
#   -1,
#   -1,
#   '2'],
#  ['San Marino',
#   '6464',
#   -1,
#   '94 ',
#   -1,
#   '5892',
#   -1,
#   '478',
#   '2',
#   '189928',
#   '2762',
#   '94861',
#   '2787242',
#   '34034 ',
#   'Europe',
#   '5',
#   '362',
#   '0',
#   -1,
#   -1,
#   '14,045'],
#  ['Guinea-Bissau',
#   '6448',
#   1.0,
#   '149 ',
#   -1,
#   '6283',
#   2.0,
#   '16',
#   -1,
#   '3168',
#   '73',
#   '108740',
#   '53432',
#   '2035102 ',
#   'Africa',
#   '316',
#   '13658',
#   '19',
#   '0.5',
#   -1,
#   '8'],
#  ['Sierra Leone',
#   '6421',
#   -1,
#   '121 ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '782',
#   '15',
#   '160729',
#   '19575',
#   '8211088 ',
#   'Africa',
#   '1279',
#   '67860',
#   '51',
#   -1,
#   -1,
#   '232'],
#  ['Dominica',
#   '6233',
#   -1,
#   '42 ',
#   -1,
#   '5768',
#   -1,
#   '423',
#   -1,
#   '86277',
#   '581',
#   '114250',
#   '1581446',
#   '72244 ',
#   'North America',
#   '12',
#   '1720',
#   '1',
#   -1,
#   -1,
#   '5,855'],
#  ['Grenada',
#   '5915',
#   -1,
#   '200 ',
#   -1,
#   '5656',
#   4.0,
#   '59',
#   -1,
#   '52217',
#   '1766',
#   '89012',
#   '785791',
#   '113277 ',
#   'North America',
#   '19',
#   '566',
#   '1',
#   -1,
#   -1,
#   '521'],
#  ['Liberia',
#   '5833',
#   -1,
#   '287 ',
#   -1,
#   '5535',
#   -1,
#   '11',
#   '2',
#   '1115',
#   '55',
#   '128246',
#   '24525',
#   '5229172 ',
#   'Africa',
#   '896',
#   '18220',
#   '41',
#   -1,
#   -1,
#   '2'],
#  ['Bermuda',
#   '5764',
#   -1,
#   '106 ',
#   -1,
#   '5634',
#   -1,
#   '24',
#   -1,
#   '93050',
#   '1711',
#   '660179',
#   '10657503',
#   '61945 ',
#   'North America',
#   '11',
#   '584',
#   '0',
#   -1,
#   -1,
#   '387'],
#  ['St. Vincent Grenadines',
#   '5722',
#   30.0,
#   '77 ',
#   -1,
#   '5111',
#   -1,
#   '534',
#   '7',
#   '51342',
#   '691',
#   '91554',
#   '821488',
#   '111449 ',
#   'North America',
#   '19',
#   '1447',
#   '1',
#   '269',
#   -1,
#   '4,791'],
#  ['Chad',
#   '5701',
#   -1,
#   '181 ',
#   -1,
#   '4874',
#   -1,
#   '646',
#   -1,
#   '333',
#   '11',
#   '157235',
#   '9192',
#   '17105427 ',
#   'Africa',
#   '3000',
#   '94505',
#   '109',
#   -1,
#   -1,
#   '38'],
#  ['Liechtenstein',
#   '5327',
#   52.0,
#   '67 ',
#   -1,
#   '4772',
#   -1,
#   '488',
#   '11',
#   '139137',
#   '1750',
#   '80413',
#   '2100324',
#   '38286 ',
#   'Europe',
#   '7',
#   '571',
#   '0',
#   '1358',
#   -1,
#   '12,746'],
#  ['Sint Maarten',
#   '4632',
#   -1,
#   '75 ',
#   -1,
#   '4524',
#   -1,
#   '33',
#   '10',
#   '106290',
#   '1721',
#   '62056',
#   '1423989',
#   '43579 ',
#   'North America',
#   '9',
#   '581',
#   '1',
#   -1,
#   -1,
#   '757'],
#  ['Comoros',
#   '4567',
#   3.0,
#   '151 ',
#   -1,
#   '4374',
#   1.0,
#   '42',
#   -1,
#   '5095',
#   '168',
#   -1,
#   -1,
#   '896331 ',
#   'Africa',
#   '196',
#   '5936',
#   -1,
#   '3',
#   -1,
#   '47'],
#  ['Faeroe Islands',
#   '4372',
#   97.0,
#   '13 ',
#   -1,
#   '3859',
#   122.0,
#   '500',
#   '7',
#   '88987',
#   '265',
#   '598000',
#   '12171541',
#   '49131 ',
#   'Europe',
#   '11',
#   '3779',
#   '0',
#   '1974',
#   -1,
#   '10,177'],
#  ['Antigua and Barbuda',
#   '4162',
#   3.0,
#   '117 ',
#   -1,
#   '4033',
#   8.0,
#   '12',
#   '1',
#   '41998',
#   '1181',
#   '18195',
#   '183601',
#   '99101 ',
#   'North America',
#   '24',
#   '847',
#   '5',
#   '30',
#   -1,
#   '121'],
#  ['Monaco',
#   '4094',
#   1.0,
#   '36 ',
#   -1,
#   '3858',
#   26.0,
#   '200',
#   '1',
#   '103269',
#   '908',
#   '54960',
#   '1386338',
#   '39644 ',
#   'Europe',
#   '10',
#   '1101',
#   '1',
#   '25',
#   -1,
#   '5,045'],
#  ['Saint Martin',
#   '3973',
#   -1,
#   '56 ',
#   -1,
#   '1399',
#   -1,
#   '2518',
#   '7',
#   '100283',
#   '1413',
#   '54303',
#   '1370665',
#   '39618 ',
#   'North America',
#   '10',
#   '707',
#   '1',
#   -1,
#   -1,
#   '63,557'],
#  ['Sao Tome and Principe',
#   '3733',
#   -1,
#   '57 ',
#   -1,
#   '3675',
#   -1,
#   '1',
#   -1,
#   '16589',
#   '253',
#   '14934',
#   '66364',
#   '225033 ',
#   'Africa',
#   '60',
#   '3948',
#   '15',
#   -1,
#   -1,
#   '4'],
#  ['Caribbean Netherlands',
#   '3138',
#   9.0,
#   '22 ',
#   -1,
#   '2973',
#   19.0,
#   '143',
#   -1,
#   '118081',
#   '828',
#   '30126',
#   '1133622',
#   '26575 ',
#   'North America',
#   '8',
#   '1208',
#   '1',
#   '339',
#   -1,
#   '5,381'],
#  ['Turks and Caicos',
#   '3137',
#   -1,
#   '25 ',
#   -1,
#   '3066',
#   -1,
#   '46',
#   -1,
#   '79472',
#   '633',
#   '94789',
#   '2401363',
#   '39473 ',
#   'North America',
#   '13',
#   '1579',
#   '0',
#   -1,
#   -1,
#   '1,165'],
#  ['British Virgin Islands',
#   '2816',
#   -1,
#   '38 ',
#   -1,
#   0,
#   0,
#   0,
#   '7',
#   '92261',
#   '1245',
#   '82570',
#   '2705262',
#   '30522 ',
#   'North America',
#   '11',
#   '803',
#   '0',
#   -1,
#   -1,
#   '4,226'],
#  ['Saint Kitts and Nevis',
#   '2796',
#   -1,
#   '28 ',
#   -1,
#   '2758',
#   -1,
#   '10',
#   '1',
#   '52025',
#   '521',
#   '57508',
#   '1070056',
#   '53743 ',
#   'North America',
#   '19',
#   '1919',
#   '1',
#   -1,
#   -1,
#   '186'],
#  ['Bhutan',
#   '2649',
#   -1,
#   '3 ',
#   -1,
#   '2629',
#   -1,
#   '17',
#   -1,
#   '3379',
#   '4',
#   '1261505',
#   '1609305',
#   '783882 ',
#   'Asia',
#   '296',
#   '261294',
#   '1',
#   -1,
#   -1,
#   '22'],
#  ['Greenland',
#   '1831',
#   18.0,
#   -1,
#   -1,
#   '1526',
#   6.0,
#   '305',
#   '2',
#   '32172',
#   -1,
#   '122048',
#   '2144504',
#   '56912 ',
#   'North America',
#   '31',
#   -1,
#   '0',
#   '316',
#   -1,
#   '5,359'],
#  ['St. Barth',
#   '1603',
#   -1,
#   '6 ',
#   -1,
#   0,
#   0,
#   0,
#   -1,
#   '161576',
#   '605',
#   '56491',
#   '5694083',
#   '9921 ',
#   'North America',
#   '6',
#   '1654',
#   '0',
#   -1,
#   -1,
#   '114,404'],
#  ['Anguilla',
#   '1523',
#   -1,
#   '4 ',
#   -1,
#   '1434',
#   -1,
#   '85',
#   -1,
#   '100224',
#   '263',
#   '51382',
#   '3381285',
#   '15196 ',
#   'North America',
#   '10',
#   '3799',
#   '0',
#   -1,
#   -1,
#   '5,594'],
#  ['Wallis and Futuna',
#   '454',
#   -1,
#   '7 ',
#   -1,
#   '438',
#   -1,
#   '9',
#   -1,
#   '41446',
#   '639',
#   '20508',
#   '1872193',
#   '10954 ',
#   'Australia/Oceania',
#   '24',
#   '1565',
#   '1',
#   -1,
#   -1,
#   '822'],
#  ['Saint Pierre Miquelon',
#   '91',
#   -1,
#   -1,
#   -1,
#   '60',
#   -1,
#   '31',
#   -1,
#   '15818',
#   -1,
#   '13137',
#   '2283504',
#   '5753 ',
#   'North America',
#   '63',
#   -1,
#   '0',
#   -1,
#   -1,
#   '5,388'],
#  ['Montserrat',
#   '44',
#   -1,
#   '1 ',
#   -1,
#   '42',
#   -1,
#   '1',
#   -1,
#   '8807',
#   '200',
#   '3037',
#   '607886',
#   '4996 ',
#   'North America',
#   '114',
#   '4996',
#   '2',
#   -1,
#   -1,
#   '200'],
#  ['Western Sahara',
#   '10',
#   -1,
#   '1 ',
#   -1,
#   '8',
#   -1,
#   '1',
#   -1,
#   '16',
#   '2',
#   -1,
#   -1,
#   '618523 ',
#   'Africa',
#   '61852',
#   '618523',
#   -1,
#   -1,
#   -1,
#   '2'],
#  ['Total:',
#   '270438946',
#   441278.0,
#   '5322062',
#   4249.0,
#   '243106547',
#   354924.0,
#   '22010337',
#   '88809',
#   '34694.8',
#   '682.8',
#   -1,
#   -1,
#   -1,
#   'All',
#   '\n',
#   -1,
#   -1,
#   -1,
#   -1,
#   -1]]

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(all_data)
df.drop([15,16,17,18,19,20],inplace=True,axis=1)
df.head()
# Out:
#        0          1         2         3       4          5         6   \
# 0   World  270438946  441278.0   5322062  4249.0  243106547  354924.0
# 1     USA   50801455   38784.0   817956    167.0   40003674   17538.0
# 2   India   34697860    7350.0  475636     202.0   34122795    8464.0
# 3  Brazil   22189867    1688.0   616941     82.0   21414318      -1.0
# 4      UK   10819515   48854.0   146439     52.0    9490407   36978.0
#
#          7      8       9      10         11       12           13  \
# 0  22010337  88809   34695  682.8         -1       -1           -1
# 1   9979825  15001  152188   2450  773733664  2317902   333807743
# 2     99429   8944   24791    340  655816759   468572  1399605867
# 3    158608   8318  103332   2873   63776166   296989   214742837
# 4   1182669    900  158177   2141  374468898  5474580    68401397
#
#               14
# 0            All
# 1  North America
# 2           Asia
# 3  South America
# 4         Europe

# %%
column_labels=["Country","Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Totlal Cases/1M","Deaths/1M","Total Tests","Test/1M","Population","Continent" ]
df.columns=column_labels

# %%
df.head()
# Out:
#   Country Total Cases  New Cases Total Deaths  New Deaths Total Recovered  \
# 0   World   270438946   441278.0      5322062      4249.0       243106547
# 1     USA    50801455    38784.0      817956        167.0        40003674
# 2   India    34697860     7350.0     475636         202.0        34122795
# 3  Brazil    22189867     1688.0      616941         82.0        21414318
# 4      UK    10819515    48854.0      146439         52.0         9490407
#
#    New Recovered Active Cases Serious/Critical Totlal Cases/1M Deaths/1M  \
# 0       354924.0     22010337            88809           34695     682.8
# 1        17538.0      9979825            15001          152188      2450
# 2         8464.0        99429             8944           24791       340
# 3           -1.0       158608             8318          103332      2873
# 4        36978.0      1182669              900          158177      2141
#
#   Total Tests  Test/1M   Population      Continent
# 0          -1       -1           -1            All
# 1   773733664  2317902   333807743   North America
# 2   655816759   468572  1399605867            Asia
# 3    63776166   296989   214742837   South America
# 4   374468898  5474580    68401397          Europe

# %%
for label in df.columns:
    if label != 'Country' and label != 'Continent':
        df[label]=pd.to_numeric(df[label])

# %%
df["%Inc Cases"]=df["New Cases"]/df["Total Cases"]*100
df["%Inc Deaths"]=df["New Deaths"]/df["Total Deaths"]*100
df["%Inc Recovered"]=df["New Recovered"]/df["Total Recovered"]*100

# %%
df.head()
# Out:
#   Country  Total Cases  New Cases  Total Deaths  New Deaths  Total Recovered  \
# 0   World    270438946   441278.0       5322062      4249.0        243106547
# 1     USA     50801455    38784.0        817956       167.0         40003674
# 2   India     34697860     7350.0        475636       202.0         34122795
# 3  Brazil     22189867     1688.0        616941        82.0         21414318
# 4      UK     10819515    48854.0        146439        52.0          9490407
#
#    New Recovered  Active Cases  Serious/Critical  Totlal Cases/1M  Deaths/1M  \
# 0       354924.0      22010337             88809          34695.0      682.8
# 1        17538.0       9979825             15001         152188.0     2450.0
# 2         8464.0         99429              8944          24791.0      340.0
# 3           -1.0        158608              8318         103332.0     2873.0
# 4        36978.0       1182669               900         158177.0     2141.0
#
#    Total Tests  Test/1M  Population      Continent  %Inc Cases  %Inc Deaths  \
# 0           -1       -1          -1            All    0.163171     0.079837
# 1    773733664  2317902   333807743  North America    0.076344     0.020417
# 2    655816759   468572  1399605867           Asia    0.021183     0.042469
# 3     63776166   296989   214742837  South America    0.007607     0.013291
# 4    374468898  5474580    68401397         Europe    0.451536     0.035510
#
#    %Inc Recovered
# 0        0.145995
# 1        0.043841
# 2        0.024805
# 3       -0.000005
# 4        0.389636

# %% [markdown]
# ## EDA

# %%
cases = df[["Total Recovered", "Active Cases","Total Deaths"]].loc[0]
cases_df=pd.DataFrame(cases).reset_index()
cases_df.columns=["Type","Total"]

cases_df["Percentage"]=np.round(100*cases_df['Total']/np.sum(cases_df["Total"]),2)
cases_df["virus"]=["COVID-19" for i in range(len(cases_df))]

cases_df
# Out:
#               Type      Total  Percentage     virus
# 0  Total Recovered  243106547       89.89  COVID-19
# 1     Active Cases   22010337        8.14  COVID-19
# 2     Total Deaths    5322062        1.97  COVID-19

# %%
fig= px.bar(cases_df, x="virus",y="Percentage", color="Type", hover_data=["Total"])

# %%
fig.show()
# Out:
# <div>                            <div id="08676642-defa-472f-8eb2-2b0db5c8259b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08676642-defa-472f-8eb2-2b0db5c8259b")) {                    Plotly.newPlot(                        "08676642-defa-472f-8eb2-2b0db5c8259b",                        [{"alignmentgroup":"True","customdata":[[243106547]],"hovertemplate":"Type=Total Recovered<br>virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Total Recovered","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Total Recovered","offsetgroup":"Total Recovered","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[89.89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[22010337]],"hovertemplate":"Type=Active Cases<br>virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Active Cases","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Active Cases","offsetgroup":"Active Cases","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[8.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[5322062]],"hovertemplate":"Type=Total Deaths<br>virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Total Deaths","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Total Deaths","offsetgroup":"Total Deaths","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[1.97],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c ...

# %%
cases = df[["New Recovered", "New Cases","New Deaths"]].loc[0]
cases_df=pd.DataFrame(cases).reset_index()
cases_df.columns=["Type","Total"]

cases_df["Percentage"]=np.round(100*cases_df['Total']/np.sum(cases_df["Total"]),2)
cases_df["virus"]=["COVID-19" for i in range(len(cases_df))]

cases_df
# Out:
#             Type     Total  Percentage     virus
# 0  New Recovered  354924.0       44.34  COVID-19
# 1      New Cases  441278.0       55.13  COVID-19
# 2     New Deaths    4249.0        0.53  COVID-19

# %%
fig= px.bar(cases_df, x="virus",y="Percentage", color="Type", hover_data=["Total"])
fig.show()
# Out:
# <div>                            <div id="da28bc3e-5e90-46f0-b763-edcd33d16b29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da28bc3e-5e90-46f0-b763-edcd33d16b29")) {                    Plotly.newPlot(                        "da28bc3e-5e90-46f0-b763-edcd33d16b29",                        [{"alignmentgroup":"True","customdata":[[354924.0]],"hovertemplate":"Type=New Recovered<br>virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New Recovered","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"New Recovered","offsetgroup":"New Recovered","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[44.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[441278.0]],"hovertemplate":"Type=New Cases<br>virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New Cases","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New Cases","offsetgroup":"New Cases","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[55.13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4249.0]],"hovertemplate":"Type=New Deaths<br>virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New Deaths","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"New Deaths","offsetgroup":"New Deaths","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[0.53],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"# ...

# %%
per = np.round(df[["%Inc Cases","%Inc Deaths","%Inc Recovered"]].loc[0],2)
per_df = pd.DataFrame(per)
per_df.columns = ["Percentage"]

fig = go.Figure()

fig.add_trace(go.Bar(x=per_df.index,y=per_df["Percentage"],marker_color=["Yellow","Blue","Red"]))
fig.show()
# Out:
# <div>                            <div id="416ea4d8-ce2a-4f57-be38-9a92f85ef1f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("416ea4d8-ce2a-4f57-be38-9a92f85ef1f4")) {                    Plotly.newPlot(                        "416ea4d8-ce2a-4f57-be38-9a92f85ef1f4",                        [{"marker":{"color":["Yellow","Blue","Red"]},"x":["%Inc Cases","%Inc Deaths","%Inc Recovered"],"y":[0.16,0.08,0.15],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorba ...
#
# var gd = document.getElementById('416ea4d8-ce2a-4f57-be38-9a92f85ef1f4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);

# %% [markdown]
# ## continent

# %%
continent_df = df.groupby("Continent").sum().drop("All")
continent_df = continent_df.reset_index()
continent_df
# Out:
#            Continent  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0             Africa      9026622    44724.0        225426        66.0
# 1               Asia     83005885    72976.0       1227764      1177.0
# 2  Australia/Oceania       389497     1743.0          4356        12.0
# 3             Europe     78109683   266190.0       1461173      2274.0
# 4      North America     60604058    46527.0       1212254       415.0
# 5      South America     39202569     8977.0       1186435       193.0
#
#    Total Recovered  New Recovered  Active Cases  Serious/Critical  \
# 0          8239645        36456.0        529676              1518
# 1         80266949        69967.0       1511172             30427
# 2           315517         1458.0         23926               159
# 3         68300629       214499.0       8347881             22961
# 4         48588551        23733.0      10798876             20887
# 5         35538747         8714.0        428010             12773
#
#    Totlal Cases/1M  Deaths/1M  Total Tests    Test/1M  Population  %Inc Cases  \
# 0        1027039.0    15491.0     82382817    8259536  1386891350   -3.290482
# 1        2443565.0    25260.0   1476720554   64245112  3218414123    7.005310
# 2         321159.0     4774.0     56035716    5539088    41610511    1.540404
# 3        5988417.0    89530.0   1611769776  138694371   748282033   15.121818
# 4        2881856.0    40461.0    868084620   58710402   595778787   -0.117034
# 5        1033272.0    27956.0    181421840    7622523   435891281    0.773521
#
#    %Inc Deaths  %Inc Recovered
# 0  -116.455399       -8.913334
# 1   -25.546079        4.676516
# 2   -14.708931        1.310357
# 3   -15.246386       16.522452
# 4    22.304929       -0.433969
# 5     0.227268        0.681891

# %%
def continent_visulaization(v_list):
    for label in v_list:
        c_df = continent_df[['Continent', label]]
        c_df["Percent"] = np.round(100*c_df[label]/np.sum(c_df[label]), 2)
        c_df['Virus']= ["Covid-19" for i in range (len(c_df))]
        
        fig= px.bar(c_df, x="Virus",y="Percent", color="Continent", hover_data=[label])
        fig.update_layout(title= {"text":label})
        fig.show()

# %%
# Out:
#   File "C:\Users\adelq\AppData\Local\Temp/ipykernel_22804/305164572.py", line 3
#     c_df['Virus']= ["Covid-19" for i in range (len(c_df))]
#     ^
# IndentationError: unexpected indent

# %%
cases_list = ["Total Cases","Active Cases","New Cases","Serious/Critical","Totlal Cases/1M"]

deaths_list = ["Total Deaths","New Deaths", "Deaths/1M"]

recovered_list = ["Total Recovered", "New Recovered", "%Inc Recovered"]

# %%
continent_visulaization(cases_list)
# Out:
# <div>                            <div id="41aaea63-4780-424e-8e30-cec12af75e2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41aaea63-4780-424e-8e30-cec12af75e2a")) {                    Plotly.newPlot(                        "41aaea63-4780-424e-8e30-cec12af75e2a",                        [{"alignmentgroup":"True","customdata":[[9026622]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percent=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[3.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[83005885]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percent=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[30.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[389497]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percent=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[78109683]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percent=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[28.89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[60604058]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percent=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[22.42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[39202569]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percent=%{y}<br>Total Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[14.5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d857 ...
# <div>                            <div id="f4299c98-7f80-40e8-813c-1e058a52db54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4299c98-7f80-40e8-813c-1e058a52db54")) {                    Plotly.newPlot(                        "f4299c98-7f80-40e8-813c-1e058a52db54",                        [{"alignmentgroup":"True","customdata":[[529676]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percent=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1511172]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percent=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[6.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[23926]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percent=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[8347881]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percent=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[38.58],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[10798876]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percent=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[49.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[428010]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percent=%{y}<br>Active Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[1.98],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576 ...
# <div>                            <div id="d8793c88-f83e-4c91-8b9c-c64713303df6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8793c88-f83e-4c91-8b9c-c64713303df6")) {                    Plotly.newPlot(                        "d8793c88-f83e-4c91-8b9c-c64713303df6",                        [{"alignmentgroup":"True","customdata":[[44724.0]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percent=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[10.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[72976.0]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percent=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[16.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1743.0]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percent=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[266190.0]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percent=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[60.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[46527.0]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percent=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[10.55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[8977.0]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percent=%{y}<br>New Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.03],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...
# <div>                            <div id="cf0416f8-7423-421a-9e60-1ead558632f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf0416f8-7423-421a-9e60-1ead558632f1")) {                    Plotly.newPlot(                        "cf0416f8-7423-421a-9e60-1ead558632f1",                        [{"alignmentgroup":"True","customdata":[[1518]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percent=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[1.71],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[30427]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percent=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[34.29],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[159]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percent=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[22961]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percent=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[25.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[20887]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percent=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[23.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[12773]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percent=%{y}<br>Serious/Critical=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[14.4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555 ...
# <div>                            <div id="07f60b65-009c-4e0f-aab9-bb9eb60ded5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07f60b65-009c-4e0f-aab9-bb9eb60ded5f")) {                    Plotly.newPlot(                        "07f60b65-009c-4e0f-aab9-bb9eb60ded5f",                        [{"alignmentgroup":"True","customdata":[[1027039.0]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percent=%{y}<br>Totlal Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[7.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2443565.0]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percent=%{y}<br>Totlal Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[17.84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[321159.0]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percent=%{y}<br>Totlal Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[2.35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[5988417.0]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percent=%{y}<br>Totlal Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[43.73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2881856.0]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percent=%{y}<br>Totlal Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[21.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1033272.0]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percent=%{y}<br>Totlal Cases/1M=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[7.54],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3 ...

# %% [markdown]
# Contries

# %%
df = df.drop([len(df)-1])
country_df = df.drop([0])

country_df
# Out:
#                    Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 1                      USA     50801455    38784.0        817956       167.0
# 2                    India     34697860     7350.0        475636       202.0
# 3                   Brazil     22189867     1688.0        616941        82.0
# 4                       UK     10819515    48854.0        146439        52.0
# 5                   Russia     10016896    29929.0        289483      1132.0
# ..                     ...          ...        ...           ...         ...
# 206               Anguilla         1523       -1.0             4        -1.0
# 207      Wallis and Futuna          454       -1.0             7        -1.0
# 208  Saint Pierre Miquelon           91       -1.0            -1        -1.0
# 209             Montserrat           44       -1.0             1        -1.0
# 210         Western Sahara           10       -1.0             1        -1.0
#
#      Total Recovered  New Recovered  Active Cases  Serious/Critical  \
# 1           40003674        17538.0       9979825             15001
# 2           34122795         8464.0         99429              8944
# 3           21414318           -1.0        158608              8318
# 4            9490407        36978.0       1182669               900
# 5            8741355        31391.0        986058              2300
# ..               ...            ...           ...               ...
# 206             1434           -1.0            85                -1
# 207              438           -1.0             9                -1
# 208               60           -1.0            31                -1
# 209               42           -1.0             1                -1
# 210                8           -1.0             1                -1
#
#      Totlal Cases/1M  Deaths/1M  Total Tests  Test/1M  Population  \
# 1           152188.0     2450.0    773733664  2317902   333807743
# 2            24791.0      340.0    655816759   468572  1399605867
# 3           103332.0     2873.0     63776166   296989   214742837
# 4           158177.0     2141.0    374468898  5474580    68401397
# 5            68597.0     1982.0    231600000  1586031   146024926
# ..               ...        ...          ...      ...         ...
# 206         100224.0      263.0        51382  3381285       15196
# 207          41446.0      639.0        20508  1872193       10954
# 208          15818.0       -1.0        13137  2283504        5753
# 209           8807.0      200.0         3037   607886        4996
# 210             16.0        2.0           -1       -1      618523
#
#              Continent  %Inc Cases  %Inc Deaths  %Inc Recovered
# 1        North America    0.076344     0.020417        0.043841
# 2                 Asia    0.021183     0.042469        0.024805
# 3        South America    0.007607     0.013291       -0.000005
# 4               Europe    0.451536     0.035510        0.389636
# 5               Europe    0.298785     0.391042        0.359109
# ..                 ...         ...          ...             ...
# 206      North America   -0.065660   -25.000000       -0.069735
# 207  Australia/Oceania   -0.220264   -14.285714       -0.228311
# 208      North America   -1.098901   100.000000       -1.666667
# 209      North America   -2.272727  -100.000000       -2.380952
# 210             Africa  -10.000000  -100.000000      -12.500000
#
# [210 rows x 18 columns]

# %%
country = country_df.columns[1:14]
LOOK_AT=5

fig=go.Figure()
c=0
for i in country_df.index:
    if c < LOOK_AT:
        fig.add_trace(go.Bar(name= country_df['Country'][i],x = country, y=country_df.loc[i][1:14]))
    else:
        break
    c +=1
    
fig.update_layout(title={"text" :f'top {LOOK_AT} countries affectted'}, yaxis_type='log')
fig.show()
# Out:
# <div>                            <div id="067c3cc6-aeb2-472a-a8c1-2014248e5dd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("067c3cc6-aeb2-472a-a8c1-2014248e5dd2")) {                    Plotly.newPlot(                        "067c3cc6-aeb2-472a-a8c1-2014248e5dd2",                        [{"name":"USA","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Totlal Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[50801455,38784.0,817956,167.0,40003674,17538.0,9979825,15001,152188.0,2450.0,773733664,2317902,333807743],"type":"bar"},{"name":"India","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Totlal Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[34697860,7350.0,475636,202.0,34122795,8464.0,99429,8944,24791.0,340.0,655816759,468572,1399605867],"type":"bar"},{"name":"Brazil","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Totlal Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[22189867,1688.0,616941,82.0,21414318,-1.0,158608,8318,103332.0,2873.0,63776166,296989,214742837],"type":"bar"},{"name":"UK","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Totlal Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[10819515,48854.0,146439,52.0,9490407,36978.0,1182669,900,158177.0,2141.0,374468898,5474580,68401397],"type":"bar"},{"name":"Russia","x":["Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Totlal Cases/1M","Deaths/1M","Total Tests","Test/1M","Population"],"y":[10016896,29929.0,289483,1132.0,8741355,31391.0,986058,2300,68597.0,1982.0,231600000,1586031,146024926],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...
